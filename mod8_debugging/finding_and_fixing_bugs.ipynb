# %% [markdown]
# # Debugging: Finding and Fixing Bugs

# %%
from TicTacToe import TicTacToe
game = TicTacToe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from TicTacToe import TicTacToe
# ----> 2 game = TicTacToe()
#
# File ~/Documents/GitHub/bwsi-intro-python/mod8_debugging/TicTacToe.py:35, in TicTacToe.__init__(self)
#      33 self.board = np.zeros([3,3])
#      34 self.valid_moves = [move.value for move in MoveType]
# ---> 35 self.print_instructions(self)
#
# TypeError: TicTacToe.print_instructions() takes 1 positional argument but 2 were given

# %%
game.play_game()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 game.play_game()
#
# NameError: name 'game' is not defined
